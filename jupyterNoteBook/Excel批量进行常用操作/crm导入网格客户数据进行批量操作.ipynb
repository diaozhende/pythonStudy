# %%
import pandas as pd
import numpy as np
import pymysql

# %%
# 读取数据库网格数据
conn = pymysql.connect("127.0.0.1","root","root","pythontestdb")
grid_data = pd.read_sql("select * from grid",con=conn)

# %%
grid_data.head()
# Out:
#       ID    NAME   CODE TYPE   SUB_BRAN SUB_BRAN_NAME BUSIMANAGER_ID  \
# 0  10001    花园小区  10001    1  281000008          杜集支行       91401017
# 1  10002    沿街商铺  10002    1  281000009          常洼支行       91401014
# 2  10003   城北商业街  10003    1  281000009          常洼支行       91401014
# 3  10004  李店沿街商铺  10004    4  281000011          长官支行       91401008
# 4  10005     地税局  10005    0  281000012          后魏支行       91401005
#
#   BUSIMANAGER_NAME GREPRESENTATIVE        PHONE  ...  BY_COUNTS2  BY_COUNTS3  \
# 0              桑奎红             桑奎红  15678563434  ...        18.0         3.0
# 1              李永鑫             李永鑫  18976543211  ...        20.0         3.0
# 2              李永鑫             谷晓洁  13578786565  ...        22.0         3.0
# 3               张然              张然  17867677676  ...        15.0         3.0
# 4              王盼盼             王盼盼            3  ...        10.0         3.0
#
#   BY_COUNTS4 BY_COUNTS5 BY_BAL1    BY_BAL2 BY_BAL3 BY_BAL4  BY_BAL5  TOWN
# ...

# %%
cust_data = pd.read_excel("C:/Users/diaozhende/Desktop/models.xlsx",dtype={"grid":str})

# %%
cust_data.head()
# Out:
#     grid  custName              cdCard
# 0  10001       312  370781199705056372
# 1  10001       312  370781199705056372
# 2  10001       312  370781199705056372
# 3  10001       312  370781199705056372
# 4  10001       312  370781199705056372

# %%
typeCount = cust_data["grid"].size

# %%
grid_data["CODE"][1]
# Out:
# '10002'

# %%
typeCount[0]
# Out:
# 33

# %%
grid_type = grid_data["ID"].shape

# %%
grid_type[0]
# Out:
# 12

# %%
for i in range(0,typeCount):
    for j in range(0,grid_type[0]):
        if cust_data["grid"][i] == grid_data["CODE"][j]:
            cust_data["grid"][i] = grid_data["NAME"][j]+"-"+grid_data["CODE"][j]+"-"+grid_data["TYPE"][j]
            break;
# Out:
# D:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
cust_data
# Out:
#              grid  custName              cdCard
# 0    花园小区-10001-1       312  370781199705056372
# 1    花园小区-10001-1       312  370781199705056372
# 2    花园小区-10001-1       312  370781199705056372
# 3    花园小区-10001-1       312  370781199705056372
# 4    花园小区-10001-1       312  370781199705056372
# 5    花园小区-10001-1       312  370781199705056372
# 6    花园小区-10001-1       312  370781199705056372
# 7    花园小区-10001-1       312  370781199705056372
# 8    花园小区-10001-1       312  370781199705056372
# 9    沿街商铺-10002-1       312  370781199705056372
# 10   沿街商铺-10002-1       312  370781199705056372
# 11   沿街商铺-10002-1       312  370781199705056372
# 12   沿街商铺-10002-1       312  370781199705056372
# 13   沿街商铺-10002-1       312  370781199705056372
# 14   沿街商铺-10002-1       312  370781199705056372
# 15   沿街商铺-10002-1       312  370781199705056372
# 16   沿街商铺-10002-1       312  370781199705056372
# 17   沿街商铺-10002-1       312  370781199705056372
# 18   沿街商铺-10002-1       312  370781199705056372
# ...
