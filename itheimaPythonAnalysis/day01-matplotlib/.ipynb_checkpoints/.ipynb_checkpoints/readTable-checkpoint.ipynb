# %%
import pandas

tableData = pandas.read_table("C:/Users/diaozhende/Desktop/table.txt")
print(tableData)
# Out:
#     <table style="color:rgb(69,69,69);font-size:16px;"><tbody style="border:0px;"><tr style="border-width:1px 0px 0px;border-top-style:solid;border-top-color:rgb(221,221,221);"><td style="color:rgb(79,79,79);">
# 0    <p style="line-height:26px;"><span style="font...
# 1                                                </td>
# 2                    <td style="color:rgb(79,79,79);">
# 3    <p style="line-height:26px;"><span style="font...
# 4                                                </td>
# 5                    <td style="color:rgb(79,79,79);">
# 6    <p style="line-height:26px;"><span style="font...
# 7                                                </td>
# 8                    <td style="color:rgb(79,79,79);">
# 9    <p style="line-height:26px;"><span style="font...
# 10                                               </td>
# 11   </tr><tr style="border-width:1px 0px 0px;borde...
# 12   <p align="center" style="line-height:26px;"><s...
# ...

# %%
import pandas
data = pandas.read_html("C:/Users/diaozhende/Desktop/1.html")
print(data)
# Out:
# [                                 0             1                     2  \
# 0                               英文            中文                   快捷键
# 1                       New Window        新建界面窗口      Ctrl + Shift + N
# 2                         New File          新建文件              Ctrl + N
# 3                        Open File          打开文件              Ctrl + O
# 4                      Open Folder         打开文件夹      Ctrl + Shift + O
# 5               Add Project Folder        加载项目目录        Ctrl + Alt + O
# 6                 Reopen Last Item      重新加载上次项目      Ctrl + Shift + T
# 7                             Save          保存文件              Ctrl + S
# 8                          Save As           另存为       Ctrl + Shift +S
# 9                        Close Tab      关闭当前编辑文档              Ctrl + W
# 10                    Close Window         关闭编辑器      Ctrl + Shift + W
# 11                            Undo            撤销              Ctrl + Z
# ...
