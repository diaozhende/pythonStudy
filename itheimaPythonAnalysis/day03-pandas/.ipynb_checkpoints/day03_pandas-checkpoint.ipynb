# %% [markdown]
# ### 1.DataFrame

# %% [markdown]
# ### 1.1DataFrame属性

# %%
# 创建一个符合正态分布的10个股票5天的涨跌幅
import numpy
gpData = numpy.random.normal(0,1,(10,5))

# %%
# 将array数组转换成DataFrame
import pandas
gpFrame = pandas.DataFrame(gpData)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e92c0cabf0ff> in <module>
#       1 # 将array数组转换成DataFrame
#       2 import pandas
# ----> 3 gpFrame = pandas.DataFrame(gpData)
#
# NameError: name 'gpData' is not defined

# %%
# shape:DataFram的形状（行，列）
gpFrame.shape
# Out:
# (10, 5)

# %%
# index：DataFrame的行索引
# 添加行索引
indexData = ["股票{}".format(i) for i in range(10)]
gpFrame = pandas.DataFrame(gpData,index=indexData)

# %%
gpFrame
# Out:
#             0         1         2         3         4
# 股票0 -0.878061  0.686175 -0.814990 -1.230243  0.897468
# 股票1 -0.141070  0.020909 -0.826320  0.070360  0.157713
# 股票2 -1.772021  0.082219 -0.776668 -0.953229 -0.560948
# 股票3  0.158976 -1.586321 -1.494493  0.252067  0.525269
# 股票4 -0.973958 -1.432124 -0.641736 -1.076696 -1.371266
# 股票5 -0.753555  0.261005 -0.017136 -0.786532 -0.708816
# 股票6  0.060144  1.421142 -0.783720  0.541599 -0.446796
# 股票7  1.484164  0.929759 -0.145969 -0.390021 -0.997887
# 股票8 -0.399614 -0.086873  0.061207 -0.965164 -0.960976
# 股票9 -0.045929  0.529964 -0.264873  1.141003 -2.005494

# %%
# columns:列索引
# 添加列索引
date = pandas.date_range(start="20180101",periods=5,freq="B")
gpFrame = pandas.DataFrame(gpData,index=indexData,columns=date)
gpFrame
# Out:
#      2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票0   -0.878061    0.686175   -0.814990   -1.230243    0.897468
# 股票1   -0.141070    0.020909   -0.826320    0.070360    0.157713
# 股票2   -1.772021    0.082219   -0.776668   -0.953229   -0.560948
# 股票3    0.158976   -1.586321   -1.494493    0.252067    0.525269
# 股票4   -0.973958   -1.432124   -0.641736   -1.076696   -1.371266
# 股票5   -0.753555    0.261005   -0.017136   -0.786532   -0.708816
# 股票6    0.060144    1.421142   -0.783720    0.541599   -0.446796
# 股票7    1.484164    0.929759   -0.145969   -0.390021   -0.997887
# 股票8   -0.399614   -0.086873    0.061207   -0.965164   -0.960976
# 股票9   -0.045929    0.529964   -0.264873    1.141003   -2.005494

# %%
# values:DateFrame中的数据，也就是array数组
gpFrame.values
# Out:
# array([[-0.87806141,  0.68617545, -0.81499003, -1.23024331,  0.89746826],
#        [-0.14107032,  0.02090882, -0.82631965,  0.07035965,  0.15771325],
#        [-1.77202069,  0.08221941, -0.77666822, -0.95322915, -0.56094756],
#        [ 0.15897625, -1.58632133, -1.49449337,  0.25206659,  0.52526877],
#        [-0.97395751, -1.43212412, -0.64173553, -1.0766956 , -1.37126612],
#        [-0.75355534,  0.26100524, -0.01713625, -0.78653177, -0.70881641],
#        [ 0.06014425,  1.42114214, -0.78372028,  0.54159935, -0.44679596],
#        [ 1.48416412,  0.92975893, -0.14596861, -0.39002076, -0.99788714],
#        [-0.39961423, -0.08687257,  0.06120738, -0.96516361, -0.96097645],
#        [-0.04592885,  0.52996358, -0.26487251,  1.14100327, -2.00549357]])

# %%
# T:将DataFrame进行转置（行变列，裂变行）
gpFrame.T
# Out:
#                  股票0       股票1       股票2       股票3       股票4       股票5  \
# 2018-01-01 -0.878061 -0.141070 -1.772021  0.158976 -0.973958 -0.753555
# 2018-01-02  0.686175  0.020909  0.082219 -1.586321 -1.432124  0.261005
# 2018-01-03 -0.814990 -0.826320 -0.776668 -1.494493 -0.641736 -0.017136
# 2018-01-04 -1.230243  0.070360 -0.953229  0.252067 -1.076696 -0.786532
# 2018-01-05  0.897468  0.157713 -0.560948  0.525269 -1.371266 -0.708816
#
#                  股票6       股票7       股票8       股票9
# 2018-01-01  0.060144  1.484164 -0.399614 -0.045929
# 2018-01-02  1.421142  0.929759 -0.086873  0.529964
# 2018-01-03 -0.783720 -0.145969  0.061207 -0.264873
# 2018-01-04  0.541599 -0.390021 -0.965164  1.141003
# 2018-01-05 -0.446796 -0.997887 -0.960976 -2.005494

# %% [markdown]
# ### 1.2、DataFrame的方法

# %%
# head(num):获取DateFrame的前num行数据
gpFrame.head()
# Out:
#      2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票0   -0.878061    0.686175   -0.814990   -1.230243    0.897468
# 股票1   -0.141070    0.020909   -0.826320    0.070360    0.157713
# 股票2   -1.772021    0.082219   -0.776668   -0.953229   -0.560948
# 股票3    0.158976   -1.586321   -1.494493    0.252067    0.525269
# 股票4   -0.973958   -1.432124   -0.641736   -1.076696   -1.371266

# %%
# tail(num):获取DataFrame的后num行数据,默认是5
gpFrame.tail(2)
# Out:
#      2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票8   -0.399614   -0.086873    0.061207   -0.965164   -0.960976
# 股票9   -0.045929    0.529964   -0.264873    1.141003   -2.005494

# %% [markdown]
# ### 1.3、DataFrame索引的设置

# %% [markdown]
# ### 1.3.1、修改行列索引值

# %%
gpFrame.head()
# Out:
#      2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票0   -0.878061    0.686175   -0.814990   -1.230243    0.897468
# 股票1   -0.141070    0.020909   -0.826320    0.070360    0.157713
# 股票2   -1.772021    0.082219   -0.776668   -0.953229   -0.560948
# 股票3    0.158976   -1.586321   -1.494493    0.252067    0.525269
# 股票4   -0.973958   -1.432124   -0.641736   -1.076696   -1.371266

# %%
# 将股票0.。。。改成股票_0.。。
index_ = ["股票_{}".format(i) for i in range(10)]
index_
# Out:
# ['股票_0',
#  '股票_1',
#  '股票_2',
#  '股票_3',
#  '股票_4',
#  '股票_5',
#  '股票_6',
#  '股票_7',
#  '股票_8',
#  '股票_9']

# %%
gpFrame.index = index_

# %%
gpFrame
# Out:
#       2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票_0   -0.878061    0.686175   -0.814990   -1.230243    0.897468
# 股票_1   -0.141070    0.020909   -0.826320    0.070360    0.157713
# 股票_2   -1.772021    0.082219   -0.776668   -0.953229   -0.560948
# 股票_3    0.158976   -1.586321   -1.494493    0.252067    0.525269
# 股票_4   -0.973958   -1.432124   -0.641736   -1.076696   -1.371266
# 股票_5   -0.753555    0.261005   -0.017136   -0.786532   -0.708816
# 股票_6    0.060144    1.421142   -0.783720    0.541599   -0.446796
# 股票_7    1.484164    0.929759   -0.145969   -0.390021   -0.997887
# 股票_8   -0.399614   -0.086873    0.061207   -0.965164   -0.960976
# 股票_9   -0.045929    0.529964   -0.264873    1.141003   -2.005494

# %%
# data.index[2] = "股票88" 不能单独修改索引

# %% [markdown]
# ### 1.3.2、重设索引

# %%
gpFrame.reset_index(drop=True)# 将索引的一列直接删除，索引变成了数字
# Out:
#    2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 0   -0.878061    0.686175   -0.814990   -1.230243    0.897468
# 1   -0.141070    0.020909   -0.826320    0.070360    0.157713
# 2   -1.772021    0.082219   -0.776668   -0.953229   -0.560948
# 3    0.158976   -1.586321   -1.494493    0.252067    0.525269
# 4   -0.973958   -1.432124   -0.641736   -1.076696   -1.371266
# 5   -0.753555    0.261005   -0.017136   -0.786532   -0.708816
# 6    0.060144    1.421142   -0.783720    0.541599   -0.446796
# 7    1.484164    0.929759   -0.145969   -0.390021   -0.997887
# 8   -0.399614   -0.086873    0.061207   -0.965164   -0.960976
# 9   -0.045929    0.529964   -0.264873    1.141003   -2.005494

# %%
gpFrame.reset_index(drop=False)# 将索引这一列变成了数据中的一列，然后重新添加了一列索引
# Out:
#   index  2018-01-01 00:00:00  2018-01-02 00:00:00  2018-01-03 00:00:00  \
# 0  股票_0            -0.878061             0.686175            -0.814990
# 1  股票_1            -0.141070             0.020909            -0.826320
# 2  股票_2            -1.772021             0.082219            -0.776668
# 3  股票_3             0.158976            -1.586321            -1.494493
# 4  股票_4            -0.973958            -1.432124            -0.641736
# 5  股票_5            -0.753555             0.261005            -0.017136
# 6  股票_6             0.060144             1.421142            -0.783720
# 7  股票_7             1.484164             0.929759            -0.145969
# 8  股票_8            -0.399614            -0.086873             0.061207
# 9  股票_9            -0.045929             0.529964            -0.264873
#
#    2018-01-04 00:00:00  2018-01-05 00:00:00
# 0            -1.230243             0.897468
# 1             0.070360             0.157713
# 2            -0.953229            -0.560948
# ...

# %% [markdown]
# ### 1.3.3、设置新索引

# %%
df = pandas.DataFrame({
    "month":[1,4,7,10],
    "year":[2012,2013,2014,2015],
    "sale":[55,44,33,22]
})
df
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2013    44
# 2      7  2014    33
# 3     10  2015    22

# %%
# 以月份设置新的索引
df.set_index("month")
# Out:
#        year  sale
# month
# 1      2012    55
# 4      2013    44
# 7      2014    33
# 10     2015    22

# %%
# 设置多个索引，以年和月份
new_df = df.set_index(["month","year"])

# %%
new_df.index
# Out:
# MultiIndex(levels=[[1, 4, 7, 10], [2012, 2013, 2014, 2015]],
#            codes=[[0, 1, 2, 3], [0, 1, 2, 3]],
#            names=['month', 'year'])

# %%
new_df.index.names
# Out:
# FrozenList(['month', 'year'])

# %%
new_df.index.codes
# Out:
# FrozenList([[0, 1, 2, 3], [0, 1, 2, 3]])

# %%
new_df.index.levels
# Out:
# FrozenList([[1, 4, 7, 10], [2012, 2013, 2014, 2015]])

# %% [markdown]
# ### 2.Panel

# %%
#  DataFrame是Series的容器，Panel是DataFrame的容器

# %%
p = pandas.Panel(numpy.arange(24).reshape(4,3,2),
                 items=list('ABCD'),
                 major_axis=pandas.date_range('20130101', periods=3),
                 minor_axis=['first', 'second'])

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 4 (items) x 3 (major_axis) x 2 (minor_axis)
# Items axis: A to D
# Major_axis axis: 2013-01-01 00:00:00 to 2013-01-03 00:00:00
# Minor_axis axis: first to second

# %%
p["A"]
# Out:
#             first  second
# 2013-01-01      0       1
# 2013-01-02      2       3
# 2013-01-03      4       5

# %%
p["D"]
# Out:
#             first  second
# 2013-01-01     18      19
# 2013-01-02     20      21
# 2013-01-03     22      23

# %%
p.major_xs("2013-01-01")
# Out:
#         A  B   C   D
# first   0  6  12  18
# second  1  7  13  19

# %%
p.minor_xs("first")
# Out:
#             A   B   C   D
# 2013-01-01  0   6  12  18
# 2013-01-02  2   8  14  20
# 2013-01-03  4  10  16  22

# %% [markdown]
# ### 3.Series

# %%
# 待索引的以为数组

# %% [markdown]
# ### 3.1、属性

# %%
# index
seriesData = gpFrame.iloc[0,:]
seriesData
# Out:
# 2018-01-01   -0.878061
# 2018-01-02    0.686175
# 2018-01-03   -0.814990
# 2018-01-04   -1.230243
# 2018-01-05    0.897468
# Freq: B, Name: 股票_0, dtype: float64

# %%
# index：获取索引
seriesData.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05'],
#               dtype='datetime64[ns]', freq='B')

# %%
# values：获取值
seriesData.values
# Out:
# array([-0.87806141,  0.68617545, -0.81499003, -1.23024331,  0.89746826])

# %%
type(seriesData.values)
# Out:
# numpy.ndarray

# %%
# 生成一个Series
pandas.Series(numpy.arange(3, 9, 2), index=["a", "b", "c"])
# Out:
# a    3
# b    5
# c    7
# dtype: int32

# %%
pandas.Series({'red':100, 'blue':200, 'green': 500, 'yellow':1000})
# Out:
# red        100
# blue       200
# green      500
# yellow    1000
# dtype: int64

# %% [markdown]
# ### 4、基本数据操作

# %% [markdown]
# ### 4.1、索引操作

# %% [markdown]
# ### 4.1.1、直接索引

# %%
data = pandas.read_csv("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/stock_day/stock_day.csv")
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# 2018-02-13  21.40  21.90  21.48  21.31   30802.45          0.28      1.32
# 2018-02-12  20.70  21.40  21.19  20.63   32445.39          0.82      4.03
# 2018-02-09  21.20  21.46  20.36  20.19   54304.01         -1.50     -6.86
# 2018-02-08  21.79  22.09  21.88  21.75   27068.16          0.09      0.41
# 2018-02-07  22.69  23.11  21.80  21.29   53853.25         -0.50     -2.24
# 2018-02-06  22.80  23.55  22.29  22.20   55555.00         -0.97     -4.17
# 2018-02-05  22.45  23.39  23.27  22.25   52341.39          0.65      2.87
# ...

# %%
# drop(["索引名"，。。。],axis=1),当axis=1是删除列索引，0删除行索引
data = data.drop(["ma5","ma10","ma20","v_ma5","v_ma10","v_ma20"],axis=1)

# %%
data.head()
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %%
# h获取数据
# data[1, 0] 不能直接进行数字索引,必须先列后行
data["open"]["2018-02-27"]
# Out:
# 23.53

# %% [markdown]
# ### 4.1.2、按名字索引(loc)

# %%
data.loc["2018-02-27"]["open"] # 先列后行
# Out:
# 23.53

# %%
data.loc["2018-02-27","open"]
# Out:
# 23.53

# %% [markdown]
# ### 4.1.3、按数字索引（iloc）

# %%
data.iloc[1, 0] # 先行后列
# Out:
# 22.8

# %%
data.head()
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %% [markdown]
# ### 4.1.4、组合索引（ix）

# %%
# 获取行第1天到第4天，['open', 'close', 'high', 'low']这个四个指标的结果
data.ix[:4,['open', 'close', 'high', 'low']] #(行，列)
# Out:
# D:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#              open  close   high    low
# 2018-02-27  23.53  24.16  25.88  23.53
# 2018-02-26  22.80  23.53  23.78  22.80
# 2018-02-23  22.88  22.82  23.37  22.71
# 2018-02-22  22.25  22.28  22.76  22.02

# %% [markdown]
# ### 4.2、赋值操作

# %%
data.open.head()
# Out:
# 2018-02-27    23.53
# 2018-02-26    22.80
# 2018-02-23    22.88
# 2018-02-22    22.25
# 2018-02-14    21.49
# Name: open, dtype: float64

# %%
data.open = 100
data.head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   100  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22   100  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %%
data.iloc[1, 0] = 222
data.head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22   100  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %% [markdown]
# ### 4.3.1、对内容排序

# %%
# 根据high和p_change两列进行排序，默认是升序，当asceding=False时为降序
data.sort_values(by=["high","p_change"],ascending=False).head()
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2015-06-10   100  36.35  33.85  32.23  269033.12          0.51      1.53
# 2015-06-12   100  35.98  35.21  34.01  159825.88          0.82      2.38
# 2017-10-31   100  35.22  34.44  32.20  361660.88          2.38      7.42
# 2015-06-15   100  34.99  31.69  31.69  199369.53         -3.52    -10.00
# 2015-06-11   100  34.98  34.39  32.51  173075.73          0.54      1.59
#
#             turnover
# 2015-06-10      9.21
# 2015-06-12      5.47
# 2017-10-31      9.05
# 2015-06-15      6.82
# 2015-06-11      5.92

# %% [markdown]
# ### 4.3.2、对索引排序

# %%
data.sort_index(ascending=False).head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22   100  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %%
# 对某一列进行排序
sr = data["p_change"]
sr.sort_values().head()
# Out:
# 2015-09-01   -10.03
# 2015-09-14   -10.02
# 2016-01-11   -10.02
# 2015-07-15   -10.02
# 2015-08-26   -10.01
# Name: p_change, dtype: float64

# %% [markdown]
# ### 5、DataFrame运算

# %% [markdown]
# ### 5.1、算数运算

# %%
# add()：加
data["open"].add(100).head()
# Out:
# 2018-02-27    123.53
# 2018-02-26    122.80
# 2018-02-23    122.88
# 2018-02-22    122.25
# 2018-02-14    121.49
# Name: open, dtype: float64

# %%
# sub()：减
data["open"].sub(10).head()
# Out:
# 2018-02-27    13.53
# 2018-02-26    12.80
# 2018-02-23    12.88
# 2018-02-22    12.25
# 2018-02-14    11.49
# Name: open, dtype: float64

# %%
data["open"]*100# 也可以用运算符
# Out:
# 2018-02-27    2353.0
# 2018-02-26    2280.0
# 2018-02-23    2288.0
# 2018-02-22    2225.0
# 2018-02-14    2149.0
# 2018-02-13    2140.0
# 2018-02-12    2070.0
# 2018-02-09    2120.0
# 2018-02-08    2179.0
# 2018-02-07    2269.0
# 2018-02-06    2280.0
# 2018-02-05    2245.0
# 2018-02-02    2240.0
# 2018-02-01    2371.0
# 2018-01-31    2385.0
# 2018-01-30    2371.0
# 2018-01-29    2440.0
# 2018-01-26    2427.0
# 2018-01-25    2499.0
# 2018-01-24    2549.0
# 2018-01-23    2515.0
# 2018-01-22    2514.0
# 2018-01-19    2460.0
# 2018-01-18    2440.0
# 2018-01-17    2442.0
# 2018-01-16    2340.0
# 2018-01-15    2401.0
# 2018-01-12    2370.0
# 2018-01-11    2367.0
# 2018-01-10    2410.0
#                ...
# 2015-04-13    1960.0
# 2015-04-10    1955.0
# 2015-04-09    1828.0
# 2015-04-08    1760.0
# 2015-04-07    1654.0
# 2015-04-03    1644.0
# 2015-04-02    1621.0
# 2015-04-01    1618.0
# 2015-03-31    1678.0
# 2015-03-30    1599.0
# 2015-03-27    1490.0
# 2015-03-26    1514.0
# ...

# %% [markdown]
# ### 5.2、逻辑运算

# %% [markdown]
# ### 5.2.1、逻辑运算（<,>,|,&）

# %%
# 例如筛选p_change > 2的日期数据
data[data["p_change"]>2].head()
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-14  21.49  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-12  20.70  21.40  21.19  20.63  32445.39          0.82      4.03
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20  turnover
# 2018-02-27  22.942  22.142  22.875  53782.64  46738.65  55576.11      2.39
# 2018-02-26  22.406  21.955  22.942  40827.52  42736.34  56007.50      1.53
# 2018-02-23  21.938  21.929  23.022  35119.58  41871.97  56372.85      1.32
# 2018-02-14  21.366  21.923  23.253  33590.21  42935.74  61716.11      0.58
# 2018-02-12  21.504  22.338  23.533  44645.16  45679.94  68686.33      0.81

# %%
data["p_change"]>2
# Out:
# 2018-02-27     True
# 2018-02-26     True
# 2018-02-23     True
# 2018-02-22    False
# 2018-02-14     True
# 2018-02-13    False
# 2018-02-12     True
# 2018-02-09    False
# 2018-02-08    False
# 2018-02-07    False
# 2018-02-06    False
# 2018-02-05     True
# 2018-02-02    False
# 2018-02-01    False
# 2018-01-31    False
# 2018-01-30    False
# 2018-01-29    False
# 2018-01-26    False
# 2018-01-25    False
# 2018-01-24    False
# 2018-01-23    False
# 2018-01-22    False
# 2018-01-19     True
# 2018-01-18    False
# 2018-01-17    False
# 2018-01-16     True
# 2018-01-15    False
# 2018-01-12     True
# 2018-01-11    False
# 2018-01-10    False
#               ...
# 2015-04-13     True
# 2015-04-10    False
# 2015-04-09     True
# 2015-04-08     True
# 2015-04-07     True
# 2015-04-03    False
# 2015-04-02    False
# 2015-04-01    False
# 2015-03-31    False
# 2015-03-30     True
# 2015-03-27     True
# 2015-03-26    False
# 2015-03-25    False
# 2015-03-24    False
# ...

# %%
# 完成一个多个逻辑判断， 筛选p_change > 2并且low > 15
data[(data["p_change"]>2) & (data["low"]>15)].head()
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-14  21.49  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-12  20.70  21.40  21.19  20.63  32445.39          0.82      4.03
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20  turnover
# 2018-02-27  22.942  22.142  22.875  53782.64  46738.65  55576.11      2.39
# 2018-02-26  22.406  21.955  22.942  40827.52  42736.34  56007.50      1.53
# 2018-02-23  21.938  21.929  23.022  35119.58  41871.97  56372.85      1.32
# 2018-02-14  21.366  21.923  23.253  33590.21  42935.74  61716.11      0.58
# 2018-02-12  21.504  22.338  23.533  44645.16  45679.94  68686.33      0.81

# %% [markdown]
# ### 5.2.2、逻辑运算函数

# %%
# query()
data.query("p_change > 2 & low > 15").head()
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-14  21.49  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-12  20.70  21.40  21.19  20.63  32445.39          0.82      4.03
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20  turnover
# 2018-02-27  22.942  22.142  22.875  53782.64  46738.65  55576.11      2.39
# 2018-02-26  22.406  21.955  22.942  40827.52  42736.34  56007.50      1.53
# 2018-02-23  21.938  21.929  23.022  35119.58  41871.97  56372.85      1.32
# 2018-02-14  21.366  21.923  23.253  33590.21  42935.74  61716.11      0.58
# 2018-02-12  21.504  22.338  23.533  44645.16  45679.94  68686.33      0.81

# %%
# isin()
# 判断'turnover'是否为4.19, 2.39
data[data["turnover"].isin([4.19, 2.39])]
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2017-07-25  23.07  24.20  23.70  22.64  167489.48          0.67      2.91
# 2016-09-28  19.88  20.98  20.86  19.71   95580.75          0.98      4.93
# 2015-04-07  16.54  17.98  17.54  16.50  122471.85          0.88      5.28
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# 2018-02-27  22.942  22.142  22.875   53782.64   46738.65   55576.11      2.39
# 2017-07-25  23.042  22.759  22.199  137135.54  156145.65  166607.70      4.19
# 2016-09-28  20.458  20.897  21.784   73619.52   69253.23  107749.35      2.39
# 2015-04-07  16.620  16.120  15.510   86769.62   97473.29   98832.94      4.19

# %% [markdown]
# ### 5.3、统计运算

# %%
data.describe()
# Out:
#              open        high       close         low         volume  \
# count  643.000000  643.000000  643.000000  643.000000     643.000000
# mean    21.272706   21.900513   21.336267   20.771835   99905.519114
# std      3.930973    4.077578    3.942806    3.791968   73879.119354
# min     12.250000   12.670000   12.360000   12.200000    1158.120000
# 25%     19.000000   19.500000   19.045000   18.525000   48533.210000
# 50%     21.440000   21.970000   21.450000   20.980000   83175.930000
# 75%     23.400000   24.065000   23.415000   22.850000  127580.055000
# max     34.990000   36.350000   35.210000   34.010000  501915.410000
#
#        price_change    p_change         ma5        ma10        ma20  \
# count    643.000000  643.000000  643.000000  643.000000  643.000000
# mean       0.018802    0.190280   21.302362   21.267656   21.200946
# std        0.898476    4.079698    3.880640    3.813602    3.686186
# min       -3.520000  -10.030000   12.520000   12.520000   12.520000
# ...

# %%
data.max(axis=0)# axis=0计算每列最大值
# Out:
# open                34.990
# high                36.350
# close               35.210
# low                 34.010
# volume          501915.410
# price_change         3.030
# p_change            10.030
# ma5                 33.696
# ma10                32.186
# ma20                29.998
# v_ma5           404443.540
# v_ma10          360028.160
# v_ma20          269280.790
# turnover            12.560
# dtype: float64

# %%
data.idxmax(axis=0) # 返回最大值的索引
# Out:
# open            2015-06-15
# high            2015-06-10
# close           2015-06-12
# low             2015-06-12
# volume          2017-10-26
# price_change    2015-06-09
# p_change        2015-08-28
# ma5             2015-06-15
# ma10            2015-06-18
# ma20            2015-06-18
# v_ma5           2017-10-26
# v_ma10          2017-11-02
# v_ma20          2017-11-15
# turnover        2017-10-26
# dtype: object

# %% [markdown]
# ### 5.4、统计运算

# %%
# 累计统计函数
# cumsum：计算前n个数的和
# cummax：计算前n个数的最大值
# cummin：计算前n个数的最小值
# cumprod：计算前n个数的积

# %%
data["p_change"].sort_index().cumsum()
# Out:
# 2015-03-02      2.62
# 2015-03-03      4.06
# 2015-03-04      5.63
# 2015-03-05      7.65
# 2015-03-06     16.16
# 2015-03-09     16.37
# 2015-03-10     18.75
# 2015-03-11     16.36
# 2015-03-12     15.03
# 2015-03-13     17.58
# 2015-03-16     20.34
# 2015-03-17     22.42
# 2015-03-18     23.28
# 2015-03-19     23.74
# 2015-03-20     23.48
# 2015-03-23     23.74
# 2015-03-24     25.69
# 2015-03-25     23.27
# 2015-03-26     20.85
# 2015-03-27     26.48
# 2015-03-30     30.60
# 2015-03-31     29.08
# 2015-04-01     29.82
# 2015-04-02     30.74
# 2015-04-03     32.08
# 2015-04-07     37.36
# 2015-04-08     42.38
# 2015-04-09     48.89
# 2015-04-10     47.92
# 2015-04-13     56.67
#                ...
# 2018-01-10    119.83
# 2018-01-11    119.33
# 2018-01-12    121.70
# 2018-01-15    118.40
# 2018-01-16    122.50
# 2018-01-17    123.32
# 2018-01-18    123.36
# 2018-01-19    125.51
# 2018-01-22    125.47
# 2018-01-23    127.02
# 2018-01-24    126.23
# 2018-01-25    122.55
# ...

# %%
data["p_change"].sort_index().cumsum().plot() #  plot():pandas集成了matplotlib，可以直接用plot进行画图

# %% [markdown]
# ### 6、读取数据

# %% [markdown]
# ### 6.1、读取csv格式数据

# %%
# csvData = pandas.read_csv("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/stock_day/stock_day2.csv",usecols=["high", "low", "open", "close"]).head()
# usecols=[]:指定读取那些列
csvData = pandas.read_csv("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/stock_day/test.csv")
csvData
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-40-a1ac704bf27e> in <module>
#       1 # csvData = pandas.read_csv("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/stock_day/stock_day2.csv",usecols=["high", "low", "open", "close"]).head()
#       2 # usecols=[]:指定读取那些列
# ----> 3 csvData = pandas.read_csv("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/stock_day/test.csv")
#       4 csvData
#
# ...

# %%
csvData.to_csv("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/stock_day/stock_day.csv",columns=["high", "low", "open", "close"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-99b33b85c96e> in <module>
# ----> 1 csvData.to_csv("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/stock_day/stock_day.csv",columns=["high", "low", "open", "close"])
#
# NameError: name 'csvData' is not defined

# %%
csvData.to_csv("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/stock_day/test1.csv",
               columns=["high", "low", "open", "close"],mode="a",header=False
              )
# index=False:不要行索引

# %% [markdown]
# ### 6.2、读取HDF2格式数据

# %%
# dataHDF = pandas.read_hdf("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/stock_data/day/day_adjfactor.h5")
# pandas.read_hdf("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/stock_data/day/day_adjfactor.h5")
import numpy
import pandas
data_h5 = pandas.read_hdf("E:/python大数据资料/黑马-Python数据挖掘基础资料/资料/day3资料/02-代码/test.h5")
# Out:
# ---------------------------------------------------------------------------
# HDF5ExtError                              Traceback (most recent call last)
# D:\Program Files\Anaconda3\lib\site-packages\pandas\io\pytables.py in open(self, mode, **kwargs)
#     602         try:
# --> 603             self._handle = tables.open_file(self._path, self._mode, **kwargs)
#     604         except (IOError) as e:  # pragma: no cover
#
# D:\Program Files\Anaconda3\lib\site-packages\tables\file.py in open_file(filename, mode, title, root_uep, filters, **kwargs)
#     319     # Finally, create the File instance, and return it
# --> 320     return File(filename, mode, title, root_uep, filters, **kwargs)
#     321
#
# D:\Program Files\Anaconda3\lib\site-packages\tables\file.py in __init__(self, filename, mode, title, root_uep, filters, **kwargs)
#     783         # Now, it is time to initialize the File extension
# --> 784         self._g_new(filename, mode, **params)
#     785
#
# ...

# %% [markdown]
# ### 6.3、读取json数据

# %%
# orient:格式
# lines：是否按行读取
data = pandas.read_json("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/test.json",orient="records",lines=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-11bc82c2d466> in <module>
#       1 # orient:格式
#       2 # lines：是否按行读取
# ----> 3 data = pandas.read_json("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/test.json",orient="records")
#
# D:\Program Files\Anaconda3\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# D:\Program Files\Anaconda3\lib\site-packages\pandas\io\json\json.py in read(self)
#     535             )
#     536         else:
# --> 537             obj = self._get_object_parser(self.data)
#     538         self.close()
# ...

# %%
# pandas.read_json("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/test.json",orient="records",lines=True)

sa = pandas.read_json("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/Sarcasm_Headlines_Dataset1.json", orient="records", lines=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-539c3fb01874> in <module>
#       1 # pandas.read_json("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/test.json",orient="records",lines=True)
#       2
# ----> 3 sa = pandas.read_json("E:/python大数据资料/Python数据挖掘基础教程教程/资料/day3资料/02-代码/Sarcasm_Headlines_Dataset1.json", orient="records", lines=True)
#
# D:\Program Files\Anaconda3\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# D:\Program Files\Anaconda3\lib\site-packages\pandas\io\json\json.py in read(self)
#     532             data = to_str(self.data)
# ...
